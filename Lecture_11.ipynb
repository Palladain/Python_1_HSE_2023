# %% [markdown]
# # Python-1, лекция 10
#
# **Лектор:** Петров Тимур

# %% [markdown]
# ## Pandas

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1L031HekamufnACOzz66AENng0em4DHhJ)

# %% [markdown]
# Все видели эту картинку (ну в общем-то это правда). Однако можно же не только Экселем пользоваться
#
# Вот для этого и есть Pandas. Помимо того, что это такие таблицы, чтобы заменить Эксель, это еще и очень удобная штука для EDA (exploratory data analysis)
#
# [Документация](https://pandas.pydata.org/docs/)

# %% [markdown]
# ### Начинаем

# %% [markdown]
# Будем смотреть это все на данных про аниме и их рейтингов
#
# ![аниме](https://steamuserimages-a.akamaihd.net/ugc/795365202390752570/FF835BAC56853D50EEAE303BFEF92369987ADEDE/?imw=512&amp;imh=400&amp;ima=fit&amp;impolicy=Letterbox&amp;imcolor=%23000000&amp;letterbox=true)

# %%
# !wget https://github.com/Palladain/Deep_Python_2023/raw/main/week03/flop_file.csv
# Out:
# --2023-09-25 06:53:04--  https://github.com/Palladain/Deep_Python_2023/raw/main/week03/flop_file.csv
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Palladain/Deep_Python_2023/main/week03/flop_file.csv [following]
# --2023-09-25 06:53:04--  https://raw.githubusercontent.com/Palladain/Deep_Python_2023/main/week03/flop_file.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 171 [text/plain]
# Saving to: ‘flop_file.csv’
#
# flop_file.csv       100%[===================>]     171  --.-KB/s    in 0s
#
# 2023-09-25 06:53:04 (11.0 MB/s) - ‘flop_file.csv’ saved [171/171]

# %%
# !wget https://github.com/Palladain/Deep_Python_2023/raw/main/week03/archive_2023.zip
# Out:
# --2023-09-25 06:38:56--  https://github.com/Palladain/Deep_Python_2023/raw/main/week03/archive_2023.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Palladain/Deep_Python_2023/main/week03/archive_2023.zip [following]
# --2023-09-25 06:38:56--  https://raw.githubusercontent.com/Palladain/Deep_Python_2023/main/week03/archive_2023.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26259955 (25M) [application/zip]
# Saving to: ‘archive_2023.zip’
#
# archive_2023.zip    100%[===================>]  25.04M   150MB/s    in 0.2s
#
# 2023-09-25 06:38:57 (150 MB/s) - ‘archive_2023.zip’ saved [26259955/26259955]

# %%
# !unzip archive_2023.zip
# Out:
# Archive:  archive_2023.zip
#   inflating: anime.csv
#   inflating: rating.csv

# %% [markdown]
# Откуда может потребоваться загрузка данных?
#
# * CSV/TXT - просто обычный файлик (данные разделены пробелами/табами/запятыми)
#
# * Словари (например, те же json-чики, если нам необходимо считать)
#
# * Excel - чаще всего приходиться выгружать, чем загружать, но тем не менее
#
# * БД - загрузки из баз данных (святое)
#
# Какие есть функции для этого?
#
# * read_csv() - считываем данные с csv/txt/файла
#
# * read_excel() - считываем данные с Экселя (какой-то из листов)
#
# * read_json() - считываем json-файл в качестве таблицы
#
# * read_sql() - считываем SQL-запрос (про это скажем в лекции про коннекторы)
#
# На самом деле их больше, вот [шпора](https://pandas.pydata.org/pandas-docs/stable/reference/io.html)
#
# Давайте на примерах:

# %%
import pandas as pd

anime = pd.read_csv('anime.csv')
rating = pd.read_csv('rating.csv')

# %% [markdown]
# Посмотрим, что там находится. Это можно сделать с помощью функций:
#
# * pd.head(n) - посмотреть первые n строк
#
# * pd.tail(n) - посмотреть последние n строк
#
# * ну или просто вызвать сам dataframe

# %%
anime.head(10)
# Out:
#    anime_id                                               name  \
# 0     32281                                     Kimi no Na wa.
# 1      5114                   Fullmetal Alchemist: Brotherhood
# 2     28977                                           Gintama°
# 3      9253                                        Steins;Gate
# 4      9969                                      Gintama&#039;
# 5     32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 6     11061                             Hunter x Hunter (2011)
# 7       820                               Ginga Eiyuu Densetsu
# 8     15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 9     15417                           Gintama&#039;: Enchousen
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
# 5             Comedy, Drama, School, Shounen, Sports     TV       10    9.15
# 6            Action, Adventure, Shounen, Super Power     TV      148    9.13
# 7                     Drama, Military, Sci-Fi, Space    OVA      110    9.11
# 8  Action, Comedy, Historical, Parody, Samurai, S...  Movie        1    9.10
# 9  Action, Comedy, Historical, Parody, Samurai, S...     TV       13    9.11
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266
# 5    93351
# 6   425855
# 7    80679
# 8    72534
# 9    81109

# %%
rating.tail(10)
# Out:
#          user_id  anime_id  rating
# 7813727    73515     13161       8
# 7813728    73515     13331       9
# 7813729    73515     13599       7
# 7813730    73515     13659       8
# 7813731    73515     14345       7
# 7813732    73515     16512       7
# 7813733    73515     17187       9
# 7813734    73515     22145      10
# 7813735    73516       790       9
# 7813736    73516      8074       9

# %% [markdown]
# А также можно посмотреть рандомные 10 строк (ну или сколько захотим):

# %%
anime.sample(10) # Вопрос: а зачем?
# Out:
#       anime_id                                        name  \
# 6517       321                      Najica Dengeki Sakusen
# 9438      8495            Mahoutsukai Haley no Speed Story
# 5437      3472                              Tenrankai no E
# 7961      1993                                Hanoka Recap
# 6132      4444                           Zero Duel Masters
# 2061     10321         Uta no☆Prince-sama♪ Maji Love 1000%
# 1005      2558       Wakakusa Monogatari: Nan to Jo-sensei
# 7329     31624                   Tomato ni Natta Otokonoko
# 8821     17957          Hello Kitty no Papa Nante Daikirai
# 3202       502  Dragon Ball Movie 1: Shen Long no Densetsu
#
#                                                   genre     type episodes  \
# 6517                      Action, Comedy, Ecchi, Sci-Fi       TV       12
# 9438                               Fantasy, Kids, Magic    Movie        1
# 5437                                             Comedy    Movie        1
# 7961                                             Sci-Fi  Special        1
# 6132                    Adventure, Comedy, Game, Sports       TV       12
# 2061      Comedy, Harem, Music, Romance, School, Shoujo       TV       13
# 1005           Drama, Historical, School, Slice of Life       TV       40
# 7329                                               Kids      ONA        1
# 8821                                Kids, Slice of Life      OVA        1
# 3202  Action, Adventure, Comedy, Fantasy, Shounen, S...    Movie        1
#
#       rating  members
# 6517    6.08     9605
# 9438    6.06      256
# 5437    6.46     1065
# 7961    4.43      471
# 6132    6.25     1217
# 2061    7.37   105723
# 1005    7.73     2577
# 7329    5.54      190
# 8821    6.63      124
# 3202    7.05    30279

# %% [markdown]
# Разбираемся в параметрах:
#
# * sep - разделитель (актуально для текстового формата, где мы задаем, как разделяются значения, по дефолту = запятая)
#
# * header - какая строка является названиями для колонок и началом вообще датасета. Если у нас нет названий колонок в файле, то мы незатейливо говорим header=None
#
# * names - название для колонок, которые мы хотим получить (что здесь важно - работает в совокупе с header)
#
# * index_col - какую колонку (по номеру или названию) использовать в качестве индекса
#
# * usecols - какие колонки нужно взять (если вы не хотите брать все колонки)
#
# * true_values/false_values - список того, какие значения, помимо True/False должны считаться таковыми (пример: если в вашем датасете ответы в виде Yes/No)
#
# * parse_dates - какие колонки являются датами
#
# * date_format - как парсить дату
#
# * dayfirst - первее день или месяц в дате
#
# * thousands - разделитель для тысяч в числе
#
# * decimal - разделитель для целой и дробной части в числе
#
# * encoding - кодирование (какое кодирование чаще всего убивает русский язык? Прааавильно, cp1252)
#
# * on_bad_lines - {"error", "warn", "skip"} (что делать с плохой строкой, если мы не хотим, чтобы вызывалась всегода ошибка и все падало)
#
# Выглядит сложно? Абсолютно, поэтому давайте на примерах поэтапно (для этого давайте посмотрим на flop_file.csv):

# %%
df = pd.read_csv("flop_file.csv")
df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-9-bac7843f3f35> in <cell line: 1>()
# ----> 1 df = pd.read_csv("flop_file.csv")
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     609
#     610     with parser:
# --> 611         return parser.read(nrows)
#     612
#     613
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1776                     columns,
#    1777                     col_dict,
# -> 1778                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1779                     nrows
#    1780                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     228         try:
#     229             if self.low_memory:
# --> 230                 chunks = self._reader.read_low_memory(nrows)
#     231                 # destructive to chunks
#     232                 data = _concatenate_chunks(chunks)
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 4, saw 2

# %%
df = pd.read_csv("flop_file.csv", sep=' ')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-10-fe7592aca273> in <cell line: 1>()
# ----> 1 df = pd.read_csv("flop_file.csv", sep=' ')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     609
#     610     with parser:
# --> 611         return parser.read(nrows)
#     612
#     613
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1776                     columns,
#    1777                     col_dict,
# -> 1778                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1779                     nrows
#    1780                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     228         try:
#     229             if self.low_memory:
# --> 230                 chunks = self._reader.read_low_memory(nrows)
#     231                 # destructive to chunks
#     232                 data = _concatenate_chunks(chunks)
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 3 fields in line 3, saw 4

# %%
df = pd.read_csv("flop_file.csv", sep=' ', on_bad_lines="warn")
df
# Out:
# Skipping line 3: expected 3 fields, saw 4
#            14            13         265
# 0      ахахах  ахахахахахах          ах
# 1   3,1415926          1000          20
# 2         yes           yes          no
# 3  2022-12-01    2022-12-31  2001-01-01

# %%
df = pd.read_csv("flop_file.csv", header=None, sep=' ', on_bad_lines="skip")
df
# Out:
#             0             1           2
# 0          14            13         265
# 1      ахахах  ахахахахахах          ах
# 2   3,1415926          1000          20
# 3         yes           yes          no
# 4  2022-12-01    2022-12-31  2001-01-01

# %%
df = pd.read_csv("flop_file.csv", names=["col_1", "col_2", "col_3"], sep=' ', on_bad_lines="skip")
df
# Out:
#         col_1         col_2       col_3
# 0          14            13         265
# 1      ахахах  ахахахахахах          ах
# 2   3,1415926          1000          20
# 3         yes           yes          no
# 4  2022-12-01    2022-12-31  2001-01-01

# %%
df = pd.read_csv("flop_file.csv", names=["col_1", "col_2", "col_3"], usecols=[0,1], sep=' ', on_bad_lines="skip")
df
# Out:
#         col_1         col_2
# 0          14            13
# 1      ахахах  ахахахахахах
# 2       очень        плохая
# 3   3,1415926          1000
# 4         yes           yes
# 5  2022-12-01    2022-12-31

# %%
df = pd.read_csv("flop_file.csv", names=["col_1", "col_2", "col_3"], usecols=[0,1], sep=' ', on_bad_lines="skip", true_values=["yes"], false_values=["no"])
df
# Out:
#         col_1         col_2
# 0          14            13
# 1      ахахах  ахахахахахах
# 2       очень        плохая
# 3   3,1415926          1000
# 4         yes           yes
# 5  2022-12-01    2022-12-31

# %% [markdown]
# Можно создать и из коробки:

# %%
df = pd.DataFrame([[1,'A', 'Ahah'],
                  [2,'B', 'Ahah'],
                  [3,'C', 'Ahaha']],
columns=['id','name', 'surname'])
df
# Out:
#    id name surname
# 0   1    A    Ahah
# 1   2    B    Ahah
# 2   3    C   Ahaha

# %% [markdown]
# Одна из важных составляющих - это копирование. Почему?
#
# Потому что очень часто вы будете видеть предупреждение, что пытаетесь изменить или сделать слайс в оригинальном датасете или в копии (и вас это будет мучать). Так что тут важно каждый раз понимать - копия или не копия
#
# Чтобы явно скопировать, мы делаем copy

# %%
anime_2 = anime.copy(deep=True) #deep говорит, что физически его надо скопировать

# %% [markdown]
# ### Как и что смотреть

# %% [markdown]
# Как вы могли догадаться, рандомный просмотр строк нам необходим в случае, если у нас данные уже как-то упорядочены (получается, что если мы берем head или tail, то мы получаем нерандомный сэмпл)
#
# А допустим, что мы реально хотим получить отсортированный массив, что тогда делать?

# %%
anime.sort_values(by=['episodes', 'rating'], ascending=[True, False])
# Out:
#        anime_id                                               name  \
# 10464     33662            Taka no Tsume 8: Yoshida-kun no X-Files
# 9595      23005                                   Mogura no Motoro
# 0         32281                                     Kimi no Na wa.
# 9078      33607                                       Kahei no Umi
# 10786     26313                    Yakusoku: Africa Mizu to Midori
# ...         ...                                                ...
# 12265     34361                           Kyonyuu Reijou MC Gakuen
# 12274     34492  Nuki Doki! Tenshi to Akuma no Sakusei Battle -...
# 12280     34312                                       Saimin Class
# 12282     34388                    Shikkoku no Shaga The Animation
# 12285     34399                                   Taimanin Asagi 3
#
#                                       genre   type episodes  rating  members
# 10464                        Comedy, Parody  Movie        1   10.00       13
# 9595                          Slice of Life  Movie        1    9.50       62
# 0      Drama, Romance, School, Supernatural  Movie        1    9.37   200630
# 9078                             Historical  Movie        1    9.33       44
# 10786                           Drama, Kids    OVA        1    9.25       53
# ...                                     ...    ...      ...     ...      ...
# 12265                                Hentai    OVA  Unknown     NaN      205
# 12274                                Hentai    OVA  Unknown     NaN      392
# 12280                                Hentai    OVA  Unknown     NaN      240
# 12282                                Hentai    OVA  Unknown     NaN      195
# 12285          Demons, Hentai, Supernatural    OVA  Unknown     NaN      485
#
# [12294 rows x 7 columns]

# %% [markdown]
# Тут мы смотрим на все столбцы, которые у нас. В данном случае все читабельно и понятно, но давайте представим логи, где у вас есть очень и очень много технических полей, которые вам ни о чем не скажут. Как же быть?
#
# Ответ - можно выбирать необходимые нам столбцы!

# %%
anime[["name", "genre", "episodes", "rating"]] #можно выбрать 1, можно несколько
# Out:
#                                                     name  \
# 0                                         Kimi no Na wa.
# 1                       Fullmetal Alchemist: Brotherhood
# 2                                               Gintama°
# 3                                            Steins;Gate
# 4                                          Gintama&#039;
# ...                                                  ...
# 12289       Toushindai My Lover: Minami tai Mecha-Minami
# 12290                                        Under World
# 12291                     Violence Gekiga David no Hoshi
# 12292  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre episodes  rating
# 0                   Drama, Romance, School, Supernatural        1    9.37
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...       64    9.26
# 2      Action, Comedy, Historical, Parody, Samurai, S...       51    9.25
# 3                                       Sci-Fi, Thriller       24    9.17
# 4      Action, Comedy, Historical, Parody, Samurai, S...       51    9.16
# ...                                                  ...      ...     ...
# 12289                                             Hentai        1    4.15
# 12290                                             Hentai        1    4.28
# 12291                                             Hentai        4    4.88
# 12292                                             Hentai        1    4.98
# 12293                                             Hentai        1    5.46
#
# [12294 rows x 4 columns]

# %% [markdown]
# Окей, вспоминаем, что у нас pandas очень похож на табличку (как будто массив массивов в NumPy). А можем ли мы работать с ним также, как и с обычным массивом?

# %%
anime[0:10:2]
# Out:
#    anime_id                                               name  \
# 0     32281                                     Kimi no Na wa.
# 2     28977                                           Gintama°
# 4      9969                                      Gintama&#039;
# 6     11061                             Hunter x Hunter (2011)
# 8     15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
# 6            Action, Adventure, Shounen, Super Power     TV      148    9.13
# 8  Action, Comedy, Historical, Parody, Samurai, S...  Movie        1    9.10
#
#    members
# 0   200630
# 2   114262
# 4   151266
# 6   425855
# 8    72534

# %%
df_anime[0:10] #построчно выглядит как будто можно

# %%
anime[0:10, 1:2] #а вот так нельзя)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(0, 10, None), slice(1, 2, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-23-6b9b4fbbae5c> in <cell line: 1>()
# ----> 1 anime[0:10, 1:2] #а вот так нельзя)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3807                 #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808                 #  the TypeError.
# -> 3809                 self._check_indexing_error(key)
#    3810                 raise
#    3811
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _check_indexing_error(self, key)
#    5923             # if key is not a scalar, directly raise an error (the code below
#    5924             # would convert to numpy arrays and raise later any way) - GH29926
# -> 5925             raise InvalidIndexError(key)
#    5926
#    5927     @cache_readonly
#
# InvalidIndexError: (slice(0, 10, None), slice(1, 2, None))

# %% [markdown]
# А почему? А просто из-за того, как устроен DataFrame
#
# На пальцах: есть два представления DataFrame внутри Pandas. Первое - в виде tuplов, прдеставляющие собой строки (поэтому всегда можно сделать первый запрос)
#
# И второй - в виде словарика типа "название колонки" - значения
#
# Поэтому операция обращения к строке отдельно и отдельно к колонкам - быстрое
#
# И поэтому обращение вначале к строкам, а потом к столбцам - долгое (а вот наоборот быстрее - почему?)

# %%
# %%time
df_anime["name"][0:100]
# Out:
# CPU times: user 316 µs, sys: 0 ns, total: 316 µs
# Wall time: 325 µs
# 0                       Kimi no Na wa.
# 1     Fullmetal Alchemist: Brotherhood
# 2                             Gintama°
# 3                          Steins;Gate
# 4                        Gintama&#039;
#                     ...
# 95       JoJo no Kimyou na Bouken (TV)
# 96          Mahou Shoujo Madoka★Magica
# 97                            Nichijou
# 98                         Psycho-Pass
# 99                           Barakamon
# Name: name, Length: 100, dtype: object

# %%
# %%time
df_anime[0:100]["name"]
# Out:
# CPU times: user 2.12 ms, sys: 0 ns, total: 2.12 ms
# Wall time: 8.96 ms
# 0                       Kimi no Na wa.
# 1     Fullmetal Alchemist: Brotherhood
# 2                             Gintama°
# 3                          Steins;Gate
# 4                        Gintama&#039;
#                     ...
# 95       JoJo no Kimyou na Bouken (TV)
# 96          Mahou Shoujo Madoka★Magica
# 97                            Nichijou
# 98                         Psycho-Pass
# 99                           Barakamon
# Name: name, Length: 100, dtype: object

# %% [markdown]
# Ну хорошо, а допустим, что я не помню названий, но вот точно знаю, какой номер колонки мне нужен? (аналогично со строчками и индексами)
#
# для этого есть loc и iloc! Сделаем в качестве индекса для наглядности названия аниме

# %%
anime = anime.set_index("name")
anime.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-5a00992c1384> in <cell line: 1>()
# ----> 1 anime = anime.set_index("name")
#       2 anime.head(5)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# KeyError: "None of ['name'] are in the columns"

# %%
anime
# Out:
#                                                     anime_id  \
# name
# Kimi no Na wa.                                         32281
# Fullmetal Alchemist: Brotherhood                        5114
# Gintama°                                               28977
# Steins;Gate                                             9253
# Gintama&#039;                                           9969
# ...                                                      ...
# Toushindai My Lover: Minami tai Mecha-Minami            9316
# Under World                                             5543
# Violence Gekiga David no Hoshi                          5621
# Violence Gekiga Shin David no Hoshi: Inma Densetsu      6133
# Yasuji no Pornorama: Yacchimae!!                       26081
#
#                                                                                                 genre  \
# name
# Kimi no Na wa.                                                   Drama, Romance, School, Supernatural
# Fullmetal Alchemist: Brotherhood                    Action, Adventure, Drama, Fantasy, Magic, Mili...
# Gintama°                                            Action, Comedy, Historical, Parody, Samurai, S...
# Steins;Gate                                                                          Sci-Fi, Thriller
# Gintama&#039;                                       Action, Comedy, Historical, Parody, Samurai, S...
# ...                                                                                               ...
# Toushindai My Lover: Minami tai Mecha-Minami                                                   Hentai
# Under World                                                                                    Hentai
# Violence Gekiga David no Hoshi                                                                 Hentai
# Violence Gekiga Shin David no Hoshi: Inma Densetsu                                             Hentai
# Yasuji no Pornorama: Yacchimae!!                                                               Hentai
#
#                                                      type episodes  rating  \
# name
# Kimi no Na wa.                                      Movie        1    9.37
# Fullmetal Alchemist: Brotherhood                       TV       64    9.26
# Gintama°                                               TV       51    9.25
# Steins;Gate                                            TV       24    9.17
# Gintama&#039;                                          TV       51    9.16
# ...                                                   ...      ...     ...
# Toushindai My Lover: Minami tai Mecha-Minami          OVA        1    4.15
# Under World                                           OVA        1    4.28
# Violence Gekiga David no Hoshi                        OVA        4    4.88
# Violence Gekiga Shin David no Hoshi: Inma Densetsu    OVA        1    4.98
# Yasuji no Pornorama: Yacchimae!!                    Movie        1    5.46
#
#                                                     members
# name
# Kimi no Na wa.                                       200630
# Fullmetal Alchemist: Brotherhood                     793665
# Gintama°                                             114262
# Steins;Gate                                          673572
# Gintama&#039;                                        151266
# ...                                                     ...
# Toushindai My Lover: Minami tai Mecha-Minami            211
# Under World                                             183
# Violence Gekiga David no Hoshi                          219
# Violence Gekiga Shin David no Hoshi: Inma Densetsu      175
# Yasuji no Pornorama: Yacchimae!!                        142
#
# [12294 rows x 6 columns]

# %%
anime.iloc[0:10,3:5]
# Out:
#                                                    episodes  rating
# name
# Kimi no Na wa.                                            1    9.37
# Fullmetal Alchemist: Brotherhood                         64    9.26
# Gintama°                                                 51    9.25
# Steins;Gate                                              24    9.17
# Gintama&#039;                                            51    9.16
# Haikyuu!!: Karasuno Koukou VS Shiratorizawa Gak...       10    9.15
# Hunter x Hunter (2011)                                  148    9.13
# Ginga Eiyuu Densetsu                                    110    9.11
# Gintama Movie: Kanketsu-hen - Yorozuya yo Eien ...        1    9.10
# Gintama&#039;: Enchousen                                 13    9.11

# %%
anime.loc["Steins;Gate":"Ginga Eiyuu Densetsu", "genre":"rating"]
# Out:
#                                                                                                 genre  \
# name
# Steins;Gate                                                                          Sci-Fi, Thriller
# Gintama&#039;                                       Action, Comedy, Historical, Parody, Samurai, S...
# Haikyuu!!: Karasuno Koukou VS Shiratorizawa Gak...             Comedy, Drama, School, Shounen, Sports
# Hunter x Hunter (2011)                                        Action, Adventure, Shounen, Super Power
# Ginga Eiyuu Densetsu                                                   Drama, Military, Sci-Fi, Space
#
#                                                    type episodes  rating
# name
# Steins;Gate                                          TV       24    9.17
# Gintama&#039;                                        TV       51    9.16
# Haikyuu!!: Karasuno Koukou VS Shiratorizawa Gak...   TV       10    9.15
# Hunter x Hunter (2011)                               TV      148    9.13
# Ginga Eiyuu Densetsu                                OVA      110    9.11

# %% [markdown]
# А теперь я хочу сделать индекс нормальным. В данному случае необходимо просто его "заресетить"

# %%
df_anime = df_anime.reset_index(names=["name"])
df_anime
# Out:
#                                                     name  anime_id  \
# 0                                         Kimi no Na wa.     32281
# 1                       Fullmetal Alchemist: Brotherhood      5114
# 2                                               Gintama°     28977
# 3                                            Steins;Gate      9253
# 4                                          Gintama&#039;      9969
# ...                                                  ...       ...
# 12289       Toushindai My Lover: Minami tai Mecha-Minami      9316
# 12290                                        Under World      5543
# 12291                     Violence Gekiga David no Hoshi      5621
# 12292  Violence Gekiga Shin David no Hoshi: Inma Dens...      6133
# 12293                   Yasuji no Pornorama: Yacchimae!!     26081
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# ...       ...      ...
# 12289    4.15      211
# 12290    4.28      183
# 12291    4.88      219
# 12292    4.98      175
# 12293    5.46      142
#
# [12294 rows x 7 columns]

# %% [markdown]
# ### Первые шаги

# %%
print(len(anime)) #сколько строк в массиве
print('-' * 30)
print(anime.info()) #описание для всех
print('-' * 30)
print(anime.describe()) # общее описание для нестроковых данных
# Out:
# 12294
# ------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB
# None
# ------------------------------
#            anime_id        rating       members
# count  12294.000000  12064.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# std    11455.294701      1.026746  5.482068e+04
# min        1.000000      1.670000  5.000000e+00
# 25%     3484.250000      5.880000  2.250000e+02
# 50%    10260.500000      6.570000  1.550000e+03
# 75%    24794.500000      7.180000  9.437000e+03
# max    34527.000000     10.000000  1.013917e+06

# %% [markdown]
# Первое, что нас напрягает - число эпизодов же тоже число, почему он object? Давайте посмотрим на все уникальные значения:

# %%
anime.episodes.unique() #вывести все уникальные значения
#Любой столбец в DataFrame - это Series. Здесь у нас array, поскольку unique() преобразовывает
#Видим Unknown, печаль
# Out:
# array(['1', '64', '51', '24', '10', '148', '110', '13', '201', '25', '22',
#        '75', '4', '26', '12', '27', '43', '74', '37', '2', '11', '99',
#        'Unknown', '39', '101', '47', '50', '62', '33', '112', '23', '3',
#        '94', '6', '8', '14', '7', '40', '15', '203', '77', '291', '120',
#        '102', '96', '38', '79', '175', '103', '70', '153', '45', '5',
#        '21', '63', '52', '28', '145', '36', '69', '60', '178', '114',
#        '35', '61', '34', '109', '20', '9', '49', '366', '97', '48', '78',
#        '358', '155', '104', '113', '54', '167', '161', '42', '142', '31',
#        '373', '220', '46', '195', '17', '1787', '73', '147', '127', '16',
#        '19', '98', '150', '76', '53', '124', '29', '115', '224', '44',
#        '58', '93', '154', '92', '67', '172', '86', '30', '276', '59',
#        '72', '330', '41', '105', '128', '137', '56', '55', '65', '243',
#        '193', '18', '191', '180', '91', '192', '66', '182', '32', '164',
#        '100', '296', '694', '95', '68', '117', '151', '130', '87', '170',
#        '119', '84', '108', '156', '140', '331', '305', '300', '510',
#        '200', '88', '1471', '526', '143', '726', '136', '1818', '237',
#        '1428', '365', '163', '283', '71', '260', '199', '225', '312',
#        '240', '1306', '1565', '773', '1274', '90', '475', '263', '83',
#        '85', '1006', '80', '162', '132', '141', '125'], dtype=object)

# %%
# Отфильтруем и посмотрим, где там Unknown
anime[anime.episodes == 'Unknown'][['name', 'genre', 'episodes']] #выберем еще конкретные колонки
# Ну это аниме, что еще не все до конца вышло (да, это старая таблица, в Наруто тут еще не кончились серии)
# Out:
#                                                     name  \
# 74                                             One Piece
# 252                                      Detective Conan
# 615                                   Naruto: Shippuuden
# 991                                     Crayon Shin-chan
# 1021              Tanaka-kun wa Itsumo Kedaruge Specials
# ...                                                  ...
# 12265                           Kyonyuu Reijou MC Gakuen
# 12274  Nuki Doki! Tenshi to Akuma no Sakusei Battle -...
# 12280                                       Saimin Class
# 12282                    Shikkoku no Shaga The Animation
# 12285                                   Taimanin Asagi 3
#
#                                                    genre episodes
# 74     Action, Adventure, Comedy, Drama, Fantasy, Sho...  Unknown
# 252          Adventure, Comedy, Mystery, Police, Shounen  Unknown
# 615    Action, Comedy, Martial Arts, Shounen, Super P...  Unknown
# 991    Comedy, Ecchi, Kids, School, Shounen, Slice of...  Unknown
# 1021                       Comedy, School, Slice of Life  Unknown
# ...                                                  ...      ...
# 12265                                             Hentai  Unknown
# 12274                                             Hentai  Unknown
# 12280                                             Hentai  Unknown
# 12282                                             Hentai  Unknown
# 12285                       Demons, Hentai, Supernatural  Unknown
#
# [340 rows x 3 columns]

# %% [markdown]
# Как исследовать колонки со строками? Можно с помощью value_counts():

# %%
anime.genre.value_counts() #тут тоже получаем Series
# Out:
# Hentai                                                  823
# Comedy                                                  523
# Music                                                   301
# Kids                                                    199
# Comedy, Slice of Life                                   179
#                                                        ...
# Adventure, Drama, Fantasy, Game, Sci-Fi                   1
# Adventure, Demons, Fantasy, Historical                    1
# Action, Comedy, Drama, Mecha, Music, Sci-Fi, Shounen      1
# Action, Comedy, Fantasy, Mecha, Sci-Fi, Shounen           1
# Hentai, Slice of Life                                     1
# Name: genre, Length: 3264, dtype: int64

# %% [markdown]
# Хотим добавить новую колонку (например, флаг, что это все аниме):

# %%
anime['is_anime'] = True
anime.head(10)
# Out:
#    anime_id                                               name  \
# 0     32281                                     Kimi no Na wa.
# 1      5114                   Fullmetal Alchemist: Brotherhood
# 2     28977                                           Gintama°
# 3      9253                                        Steins;Gate
# 4      9969                                      Gintama&#039;
# 5     32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 6     11061                             Hunter x Hunter (2011)
# 7       820                               Ginga Eiyuu Densetsu
# 8     15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 9     15417                           Gintama&#039;: Enchousen
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
# 5             Comedy, Drama, School, Shounen, Sports     TV       10    9.15
# 6            Action, Adventure, Shounen, Super Power     TV      148    9.13
# 7                     Drama, Military, Sci-Fi, Space    OVA      110    9.11
# 8  Action, Comedy, Historical, Parody, Samurai, S...  Movie        1    9.10
# 9  Action, Comedy, Historical, Parody, Samurai, S...     TV       13    9.11
#
#    members  is_anime
# 0   200630      True
# 1   793665      True
# 2   114262      True
# 3   673572      True
# 4   151266      True
# 5    93351      True
# 6   425855      True
# 7    80679      True
# 8    72534      True
# 9    81109      True

# %% [markdown]
# А допустим хотим удалить, это делается вот так (удалим из копии):

# %%
anime_2.drop(['rating', 'members'], axis=1).head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes
# 0               Drama, Romance, School, Supernatural  Movie        1
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                   Sci-Fi, Thriller     TV       24
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51

# %% [markdown]
# Отдельно для столбцов можно смотреть суммы, среднее, минимум/максимум, медиану, а также стандартное отклонение:

# %%
print(anime.rating.sum())
print('-' * 30)
print(anime.rating.mean())
print('-' * 30)
print(anime.rating.std())
print('-' * 30)
print(anime.rating.min())
print('-' * 30)
print(anime.rating.max())
print('-' * 30)
print(anime.rating.median())
# Out:
# 78101.15
# ------------------------------
# 6.473901690981432
# ------------------------------
# 1.0267463068980571
# ------------------------------
# 1.67
# ------------------------------
# 10.0
# ------------------------------
# 6.57

# %% [markdown]
# ### Слияние строк и поиск по строкам

# %% [markdown]
# Допустим, мы хотим добавить новое аниме (допустим, [Атаку титанов](https://en.wikipedia.org/wiki/Attack_on_Titan_(TV_series))):

# %%
print(list(anime.columns)) #посмотрели колонки

new_anime = pd.DataFrame([['Attack on Titans', 'Action, Dark fantasy', 'TV', '87', 9.0, 100000, True]]
                         , columns = list(anime.columns))
new_anime
# Out:
# ['name', 'genre', 'type', 'episodes', 'rating', 'members', 'is_anime']
#                name                 genre type episodes  rating  members  \
# 0  Attack on Titans  Action, Dark fantasy   TV       87     9.0   100000
#
#    is_anime
# 0      True

# %%
anime = pd.concat([anime, new_anime]) #есть еще ignore_index, если его проставить, то тогда индекс поменяется на от 0 до конца
anime #ура, доабвили
# Out:
#                                                     name  \
# 32281                                     Kimi no Na wa.
# 5114                    Fullmetal Alchemist: Brotherhood
# 28977                                           Gintama°
# 9253                                         Steins;Gate
# 9969                                       Gintama&#039;
# ...                                                  ...
# 5543                                         Under World
# 5621                      Violence Gekiga David no Hoshi
# 6133   Violence Gekiga Shin David no Hoshi: Inma Dens...
# 26081                   Yasuji no Pornorama: Yacchimae!!
# 0                                       Attack on Titans
#
#                                                    genre   type episodes  \
# 32281               Drama, Romance, School, Supernatural  Movie        1
# 5114   Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 28977  Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 9253                                    Sci-Fi, Thriller     TV       24
# 9969   Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 5543                                              Hentai    OVA        1
# 5621                                              Hentai    OVA        4
# 6133                                              Hentai    OVA        1
# 26081                                             Hentai  Movie        1
# 0                                   Action, Dark fantasy     TV       87
#
#        rating  members  is_anime
# 32281    9.37   200630      True
# 5114     9.26   793665      True
# 28977    9.25   114262      True
# 9253     9.17   673572      True
# 9969     9.16   151266      True
# ...       ...      ...       ...
# 5543     4.28      183      True
# 5621     4.88      219      True
# 6133     4.98      175      True
# 26081    5.46      142      True
# 0        9.00   100000      True
#
# [12295 rows x 7 columns]

# %% [markdown]
# Ладно, удалим для простоты:

# %%
anime = anime.drop([0])
anime
# Out:
#                                                     name  \
# 32281                                     Kimi no Na wa.
# 5114                    Fullmetal Alchemist: Brotherhood
# 28977                                           Gintama°
# 9253                                         Steins;Gate
# 9969                                       Gintama&#039;
# ...                                                  ...
# 9316        Toushindai My Lover: Minami tai Mecha-Minami
# 5543                                         Under World
# 5621                      Violence Gekiga David no Hoshi
# 6133   Violence Gekiga Shin David no Hoshi: Inma Dens...
# 26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 32281               Drama, Romance, School, Supernatural  Movie        1
# 5114   Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 28977  Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 9253                                    Sci-Fi, Thriller     TV       24
# 9969   Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 9316                                              Hentai    OVA        1
# 5543                                              Hentai    OVA        1
# 5621                                              Hentai    OVA        4
# 6133                                              Hentai    OVA        1
# 26081                                             Hentai  Movie        1
#
#        rating  members  is_anime
# 32281    9.37   200630      True
# 5114     9.26   793665      True
# 28977    9.25   114262      True
# 9253     9.17   673572      True
# 9969     9.16   151266      True
# ...       ...      ...       ...
# 9316     4.15      211      True
# 5543     4.28      183      True
# 5621     4.88      219      True
# 6133     4.98      175      True
# 26081    5.46      142      True
#
# [12294 rows x 7 columns]

# %% [markdown]
# ### Сортировка и агрегация

# %% [markdown]
# Хотим посмотреть самые худшие аниме по версии людей:

# %%
anime.sort_values('rating', ascending=True).head(10) # что такое жанр Dementia...
# Out:
#                                      name  \
# 34476  Platonic Chain: Ansatsu Jikkouchuu
# 20007       Hi Gekiga Ukiyoe Senya Ichiya
# 3287         Tenkuu Danzai Skelter+Heaven
# 13405                  Utsu Musume Sayuri
# 413                       Hametsu no Mars
# 14781             Roboteuwang Sseonsyakeu
# 24259    Mechano: Scientific Attack Force
# 33863                               Cakes
# 31634                            Kokuhaku
# 29949                                Nami
#
#                                                   genre     type episodes  \
# 34476                             Sci-Fi, Slice of Life  Special        1
# 20007                                    Action, Hentai    Movie        1
# 3287                                      Mecha, Sci-Fi      OVA        1
# 13405                                  Comedy, Dementia      OVA        1
# 413                                      Horror, Sci-Fi      OVA        1
# 14781                             Action, Mecha, Sci-Fi    Movie        1
# 24259  Comedy, Dementia, Fantasy, Horror, Music, Parody      OVA        3
# 33863                                            Comedy      ONA  Unknown
# 31634                                            Horror      ONA        1
# 29949                                          Dementia    Movie        1
#
#        rating  members  is_anime
# 34476    1.67       51      True
# 20007    1.92      129      True
# 3287     2.00     7680      True
# 13405    2.14     4047      True
# 413      2.37    27557      True
# 14781    2.49      121      True
# 24259    2.55      120      True
# 33863    2.58       56      True
# 31634    2.67      816      True
# 29949    2.67     1817      True

# %% [markdown]
# Хотим теперь агрегировать какие-нибудь значения (например, хочу узнать по типу средний рейтинг, а еще их число). Это можно сделать с помощью groupby (тут уже синтаксис становится все более похожим на SQL):

# %%
anime.groupby(["type"]).agg({"rating": "mean"}).reset_index() #красота, можно использовать
# Out:
#       type    rating
# 0    Movie  6.318058
# 1    Music  5.588996
# 2      ONA  5.643298
# 3      OVA  6.375221
# 4  Special  6.523501
# 5       TV  6.902299

# %% [markdown]
# ### JOIN THE NAVY

# %% [markdown]
# Не забудем, что у нас еще есть таблица rating. Давайте на нее посмотрим отдельно:

# %%
rating.head(5)
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %% [markdown]
# Видим anime_id, как и в исходной таблице. Теперь бы нам join сделать было бы хорошо. Давайте так и сделаем:

# %%
anime.join(rating.set_index('anime_id'), lsuffix='_anime', rsuffix='_user')
#чтобы смапить нужен общий индекс, если есть одинаковые колонки (rating), то добавляем суффиксы, дабы не было коллизий
# Out:
#                                                     name  \
# 1                                           Cowboy Bebop
# 1                                           Cowboy Bebop
# 1                                           Cowboy Bebop
# 1                                           Cowboy Bebop
# 1                                           Cowboy Bebop
# ...                                                  ...
# 34514                                Pokemon Generations
# 34519                Mobile Suit Gakuen: G-Reco Koushien
# 34522                          Wake Up, Girls! Shin Shou
# 34525                                  Centaur no Nayami
# 34527  Gou-chan. Moko to Chinjuu no Mori no Nakama-tachi
#
#                                                  genre     type episodes  \
# 1      Action, Adventure, Comedy, Drama, Sci-Fi, Space       TV       26
# 1      Action, Adventure, Comedy, Drama, Sci-Fi, Space       TV       26
# 1      Action, Adventure, Comedy, Drama, Sci-Fi, Space       TV       26
# 1      Action, Adventure, Comedy, Drama, Sci-Fi, Space       TV       26
# 1      Action, Adventure, Comedy, Drama, Sci-Fi, Space       TV       26
# ...                                                ...      ...      ...
# 34514           Action, Adventure, Fantasy, Game, Kids      ONA       18
# 34519                                           Comedy  Special        9
# 34522                                     Drama, Music       TV  Unknown
# 34525     Comedy, Fantasy, Slice of Life, Supernatural       TV  Unknown
# 34527                                  Adventure, Kids    Movie        1
#
#        rating_anime  members  is_anime  user_id  rating_user
# 1              8.82   486824      True     13.0         -1.0
# 1              8.82   486824      True     19.0         10.0
# 1              8.82   486824      True     21.0          9.0
# 1              8.82   486824      True     23.0          9.0
# 1              8.82   486824      True     32.0         10.0
# ...             ...      ...       ...      ...          ...
# 34514          7.21      295      True      NaN          NaN
# 34519          5.67       94      True  48766.0         -1.0
# 34522           NaN      381      True      NaN          NaN
# 34525           NaN      108      True      NaN          NaN
# 34527           NaN        5      True      NaN          NaN
#
# [7814824 rows x 9 columns]

# %% [markdown]
# ### Apply

# %% [markdown]
# Есть очень крутая фича, называется apply. Допустим, что мы хотим создать колонку, где будет отмечать контент 18+ (то есть по жанру Хентай). С помощью apply, смотря на значение и применив лямбда-функцию, мы получим то, что нужно:

# %%
anime
# Out:
#                                                     name  \
# 32281                                     Kimi no Na wa.
# 5114                    Fullmetal Alchemist: Brotherhood
# 28977                                           Gintama°
# 9253                                         Steins;Gate
# 9969                                       Gintama&#039;
# ...                                                  ...
# 9316        Toushindai My Lover: Minami tai Mecha-Minami
# 5543                                         Under World
# 5621                      Violence Gekiga David no Hoshi
# 6133   Violence Gekiga Shin David no Hoshi: Inma Dens...
# 26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 32281               Drama, Romance, School, Supernatural  Movie        1
# 5114   Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 28977  Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 9253                                    Sci-Fi, Thriller     TV       24
# 9969   Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 9316                                              Hentai    OVA        1
# 5543                                              Hentai    OVA        1
# 5621                                              Hentai    OVA        4
# 6133                                              Hentai    OVA        1
# 26081                                             Hentai  Movie        1
#
#        rating  members  is_anime
# 32281    9.37   200630      True
# 5114     9.26   793665      True
# 28977    9.25   114262      True
# 9253     9.17   673572      True
# 9969     9.16   151266      True
# ...       ...      ...       ...
# 9316     4.15      211      True
# 5543     4.28      183      True
# 5621     4.88      219      True
# 6133     4.98      175      True
# 26081    5.46      142      True
#
# [12294 rows x 7 columns]

# %%
anime.genre.unique()
# Out:
# array(['Drama, Romance, School, Supernatural',
#        'Action, Adventure, Drama, Fantasy, Magic, Military, Shounen',
#        'Action, Comedy, Historical, Parody, Samurai, Sci-Fi, Shounen',
#        ..., 'Hentai, Sports', 'Drama, Romance, School, Yuri',
#        'Hentai, Slice of Life'], dtype=object)

# %%
anime["adult"] = anime.genre.apply(lambda x: int('Hentai' in str(x))) # то есть берем значения в genre, для них берем лямбда функцию и итерируемся
anime
# Out:
#                                                     name  \
# 32281                                     Kimi no Na wa.
# 5114                    Fullmetal Alchemist: Brotherhood
# 28977                                           Gintama°
# 9253                                         Steins;Gate
# 9969                                       Gintama&#039;
# ...                                                  ...
# 9316        Toushindai My Lover: Minami tai Mecha-Minami
# 5543                                         Under World
# 5621                      Violence Gekiga David no Hoshi
# 6133   Violence Gekiga Shin David no Hoshi: Inma Dens...
# 26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 32281               Drama, Romance, School, Supernatural  Movie        1
# 5114   Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 28977  Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 9253                                    Sci-Fi, Thriller     TV       24
# 9969   Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 9316                                              Hentai    OVA        1
# 5543                                              Hentai    OVA        1
# 5621                                              Hentai    OVA        4
# 6133                                              Hentai    OVA        1
# 26081                                             Hentai  Movie        1
#
#        rating  members  is_anime  adult
# 32281    9.37   200630      True      0
# 5114     9.26   793665      True      0
# 28977    9.25   114262      True      0
# 9253     9.17   673572      True      0
# 9969     9.16   151266      True      0
# ...       ...      ...       ...    ...
# 9316     4.15      211      True      1
# 5543     4.28      183      True      1
# 5621     4.88      219      True      1
# 6133     4.98      175      True      1
# 26081    5.46      142      True      1
#
# [12294 rows x 8 columns]

# %%
def f(x):
    return x[0] * x[1]

anime["sum_r"] =  anime[["rating", "members"]].apply(lambda x: f(x), axis= 1)

# %%
anime
# Out:
#                                                     anime_id  \
# name
# Kimi no Na wa.                                         32281
# Fullmetal Alchemist: Brotherhood                        5114
# Gintama°                                               28977
# Steins;Gate                                             9253
# Gintama&#039;                                           9969
# ...                                                      ...
# Toushindai My Lover: Minami tai Mecha-Minami            9316
# Under World                                             5543
# Violence Gekiga David no Hoshi                          5621
# Violence Gekiga Shin David no Hoshi: Inma Densetsu      6133
# Yasuji no Pornorama: Yacchimae!!                       26081
#
#                                                                                                 genre  \
# name
# Kimi no Na wa.                                                   Drama, Romance, School, Supernatural
# Fullmetal Alchemist: Brotherhood                    Action, Adventure, Drama, Fantasy, Magic, Mili...
# Gintama°                                            Action, Comedy, Historical, Parody, Samurai, S...
# Steins;Gate                                                                          Sci-Fi, Thriller
# Gintama&#039;                                       Action, Comedy, Historical, Parody, Samurai, S...
# ...                                                                                               ...
# Toushindai My Lover: Minami tai Mecha-Minami                                                   Hentai
# Under World                                                                                    Hentai
# Violence Gekiga David no Hoshi                                                                 Hentai
# Violence Gekiga Shin David no Hoshi: Inma Densetsu                                             Hentai
# Yasuji no Pornorama: Yacchimae!!                                                               Hentai
#
#                                                      type episodes  rating  \
# name
# Kimi no Na wa.                                      Movie        1    9.37
# Fullmetal Alchemist: Brotherhood                       TV       64    9.26
# Gintama°                                               TV       51    9.25
# Steins;Gate                                            TV       24    9.17
# Gintama&#039;                                          TV       51    9.16
# ...                                                   ...      ...     ...
# Toushindai My Lover: Minami tai Mecha-Minami          OVA        1    4.15
# Under World                                           OVA        1    4.28
# Violence Gekiga David no Hoshi                        OVA        4    4.88
# Violence Gekiga Shin David no Hoshi: Inma Densetsu    OVA        1    4.98
# Yasuji no Pornorama: Yacchimae!!                    Movie        1    5.46
#
#                                                     members       sum_r
# name
# Kimi no Na wa.                                       200630  1879903.10
# Fullmetal Alchemist: Brotherhood                     793665  7349337.90
# Gintama°                                             114262  1056923.50
# Steins;Gate                                          673572  6176655.24
# Gintama&#039;                                        151266  1385596.56
# ...                                                     ...         ...
# Toushindai My Lover: Minami tai Mecha-Minami            211      875.65
# Under World                                             183      783.24
# Violence Gekiga David no Hoshi                          219     1068.72
# Violence Gekiga Shin David no Hoshi: Inma Densetsu      175      871.50
# Yasuji no Pornorama: Yacchimae!!                        142      775.32
#
# [12294 rows x 7 columns]

# %% [markdown]
# ### Запись

# %% [markdown]
# Поработали и хватит. Давайте запишем наши данные, чтобы они были и нам не пришлось все запускать заново:

# %%
anime.to_csv("anime_new.csv") #запиываем в csv

# %% [markdown]
# ## Животное дня

# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/1/1e/Ambystoma_mexicanum_%286337857516%29.jpg/1920px-Ambystoma_mexicanum_%286337857516%29.jpg)

# %% [markdown]
# Сегодня у нас известное всем животное - амбистома (и аксолотль)
#
# В чем разница? Аксолотль - это амбистомы до тех пор, пока они не станут взрослыми (то есть это лишь этап). Половозрелые амбистомы выглядят вот так:

# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/0/00/Axolotl_ganz.jpg)

# %% [markdown]
# Аксолотль не может самостоятельно стать взрослой, потому что для взросления ей необходим тироксин, которые они сами вообще не вырабатывают (то есть взрослыми они становятся за счет внешних причин, например, засухи)
#
# И для амбистом оставаться аксолотлем, видимо, максимально выгодно!
#
# Аксолотли обладают фантастической способоностью к регенерации - они даже могут мозг регенирировать (не все части, но все-таки), не оставляя на себе никаких шрамов. Поэтому ученые их используют для изучения как идеальную модель
#
# Но к сожалению они вымирают, потому что раньше ацтеки их ели, а потом пришли конкистадоры, естественно, испортили их среду обитания, да и сейчас ситуация еще хуже (из-за загрязнения воды в Мексике)
